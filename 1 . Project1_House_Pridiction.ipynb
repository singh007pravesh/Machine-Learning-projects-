# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('housing.data',header=None,delim_whitespace=True)

# %%
col=['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV']

# %%
df.columns=col

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
x = df.iloc[:,0:13]

# %%
x.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
y = df.iloc[:,13:]

# %%
y.head()
# Out:
#    MEDV
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2

# %%
sns.jointplot(x=df['CRIM'],y=df['MEDV'],kind='reg')

# %%
sns.jointplot(x=df['ZN'],y=df['MEDV'],kind='reg')

# %%
sns.jointplot(x=df['INDUS'],y=df['MEDV'],kind='reg')

# %%
sns.jointplot(x=df['CHAS'],y=df['MEDV'],kind='reg')

# %%
sns.jointplot(x=df['NOX'],y=df['MEDV'],kind='reg')

# %%
sns.jointplot(x=df['RM'],y=df['MEDV'],kind='reg')

# %%
sns.jointplot(x=df['AGE'],y=df['MEDV'],kind='reg')

# %%
sns.jointplot(x=df['DIS'],y=df['MEDV'],kind='reg')

# %%
sns.jointplot(x=df['RAD'],y=df['MEDV'],kind='reg')

# %%
sns.jointplot(x=df['TAX'],y=df['MEDV'],kind='reg')

# %%
sns.jointplot(x=df['PTRATIO'],y=df['MEDV'],kind='reg')

# %%
sns.jointplot(x=df['B'],y=df['MEDV'],kind='reg')

# %%
sns.jointplot(x=df['LSTAT'],y=df['MEDV'],kind='reg')

# %%
from sklearn.model_selection import train_test_split
x_train, x_test , y_train,y_test= train_test_split(x,y,test_size=0.4,random_state=10)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pred=model.predict(x_test)

# %%
pred
# Out:
# array([[31.22099406],
#        [32.3571748 ],
#        [30.74097887],
#        [22.51964531],
#        [18.30549566],
#        [16.24510005],
#        [36.14692108],
#        [14.81737805],
#        [25.76570226],
#        [37.33377132],
#        [21.37917755],
#        [31.71113755],
#        [27.86454739],
#        [33.94823703],
#        [34.65963991],
#        [41.14742641],
#        [24.46277721],
#        [22.88277121],
#        [25.48820039],
#        [22.16296056],
#        [32.66799999],
#        [17.62110824],
#        [25.28342115],
#        [25.00841798],
#        [32.78762189],
#        [20.22848149],
#        [19.58873838],
#        [16.75709811],
#        [39.53395021],
#        [ 0.67281923],
#        [32.86838205],
#        [32.12940392],
#        [25.90573921],
#        [24.24379212],
#        [20.57504261],
#        [19.50927529],
#        [ 4.53673509],
#        [35.28043006],
#        [26.81964504],
#        [27.4931981 ],
#        [35.19134906],
# ...

# %%
model.score(x_test,y_test)
# Out:
# 0.7056240292160211

# %%
x_train
# Out:
#          CRIM    ZN  INDUS  CHAS     NOX     RM    AGE     DIS  RAD    TAX  \
# 170   1.20742   0.0  19.58     0  0.6050  5.875   94.6  2.4259    5  403.0
# 432   6.44405   0.0  18.10     0  0.5840  6.425   74.8  2.2004   24  666.0
# 480   5.82401   0.0  18.10     0  0.5320  6.242   64.7  3.4242   24  666.0
# 281   0.03705  20.0   3.33     0  0.4429  6.968   37.2  5.2447    5  216.0
# 92    0.04203  28.0  15.04     0  0.4640  6.442   53.6  3.6659    4  270.0
# 199   0.03150  95.0   1.47     0  0.4030  6.975   15.3  7.6534    3  402.0
# 106   0.17120   0.0   8.56     0  0.5200  5.836   91.9  2.2110    5  384.0
# 29    1.00245   0.0   8.14     0  0.5380  6.674   87.3  4.2390    4  307.0
# 300   0.04417  70.0   2.24     0  0.4000  6.871   47.4  7.8278    5  358.0
# 191   0.06911  45.0   3.44     0  0.4370  6.739   30.8  6.4798    5  398.0
# 264   0.55007  20.0   3.97     0  0.6470  7.206   91.6  1.9301    5  264.0
# ...

# %%
mypred= model.predict([[1.20742,0.0,19.58,0,0.6050,5.875,94.6,2.4259,5,403.0,14.7,292.29,14.43]])
mypred
# Out:
# array([[22.01744476]])

# %%
mypred1= model.predict([[2.20742,0.0,19.58,0,0.6050,5.875,94.6,2.4259,5,403.0,14.7,292.29,14.43]])
mypred1
# Out:
# array([[21.87191238]])

# %%
mypred2= model.predict([[3.20742,0.0,19.58,0,0.6050,5.875,94.6,2.4259,5,403.0,14.7,292.29,14.43]])
mypred2
# Out:
# array([[21.72638001]])

# %%
mypred3= model.predict([[4.20742,0.0,19.58,0,0.6050,5.875,94.6,2.4259,5,403.0,14.7,292.29,14.43]])
mypred3
# Out:
# array([[21.58084764]])

# %%
mypred4= model.predict([[10.20742,0.0,19.58,0,0.6050,5.875,94.6,2.4259,5,403.0,14.7,292.29,14.43]])
mypred4
# Out:
# array([[20.7076534]])

# %%
mypred5= model.predict([[100.20742,0.0,19.58,0,0.6050,5.875,94.6,2.4259,5,403.0,14.7,292.29,14.43]])
mypred5
# Out:
# array([[7.60973985]])

# %%
mypred6 =model.predict([[0.02729,0.0,7.07,0,0.4690,7.185,61.1,4.9671,2,242.0,17.8,392.83,4.03]])
mypred6
# Out:
# array([[30.28165843]])

# %%
model.intercept_
# Out:
# array([31.47869618])

# %%
model.coef_
# Out:
# array([[-1.45532373e-01,  6.06719496e-02, -5.91600301e-04,
#          2.35546814e+00, -1.60239131e+01,  3.95519298e+00,
#          1.06698422e-04, -1.56276820e+00,  2.68553455e-01,
#         -1.17977215e-02, -8.36023608e-01,  1.21929607e-02,
#         -4.78020357e-01]])

# %%
from sklearn import metrics

# %%
metrics.mean_absolute_error(y_test,pred)
# Out:
# 3.4003389582806594

# %%
metrics.mean_squared_error(y_test,pred)
# Out:
# 26.750026400940225

# %%
np.sqrt(metrics.mean_squared_error(y_test,pred))
# Out:
# 5.172042768668897
